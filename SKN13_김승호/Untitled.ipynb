# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv("자동차등록현황보고_자동차등록대수현황 시도별 (201101 ~ 202502).csv",encoding = "cp949",skiprows=5)

# %%
cars
# Out:
#      월(Monthly) 시도명      시군구     관용      자가용     영업용        계   관용.1   자가용.1  \
# 0       2023-01  서울      강남구    154  207,692  19,642  227,488     54   4,112
# 1       2023-01  서울      강동구    102  128,422   5,111  133,635     43   3,569
# 2       2023-01  서울      강북구    103   60,998   2,066   63,167     66   2,411
# 3       2023-01  서울      강서구    129  167,350  11,195  178,674     48   4,632
# 4       2023-01  서울      관악구     91   99,804   3,123  103,018     46   3,334
# ...         ...  ..      ...    ...      ...     ...      ...    ...     ...
# 7025    2025-02  전북  전주시 덕진구    144  151,866   3,123  155,133    105   3,336
# 7026    2025-02  전북  전주시 완산구    344  137,250   2,028  139,622    232   2,979
# 7027    2025-02  전북      정읍시    109   41,310   1,646   43,065    114   1,528
# 7028    2025-02  전북      진안군    111    9,755      86    9,952     54     415
# 7029    2025-02  전북        계  1,993  761,140  12,734  775,867  1,392  22,907
#
# ...

# %%
cars.columns = ['일시', '시도명', '시군구', '승용_관용', '승용_자가용', '승용_영업용', '승용_계',
              '승합_관용', '승합_자가용', '승합_영업용', '승합_계',
              '화물_관용', '화물_자가용', '화물_영업용', '화물_계',
              '특수_관용', '특수_자가용', '특수_영업용', '특수_계',
              '총계_관용', '총계_자가용', '총계_영업용', '총계']

# %%
cars[['일시','승용_영업용']]
# Out:
#            일시  승용_영업용
# 0     2023-01  19,642
# 1     2023-01   5,111
# 2     2023-01   2,066
# 3     2023-01  11,195
# 4     2023-01   3,123
# ...       ...     ...
# 7025  2025-02   3,123
# 7026  2025-02   2,028
# 7027  2025-02   1,646
# 7028  2025-02      86
# 7029  2025-02  12,734
#
# [7030 rows x 2 columns]

# %%
cars = cars[(cars['시도명'] == '서울') & (cars['시군구'] == '강남구')]
# 강원 지역 2011년 1월부터 2019년 12월까지 데이터 필터링

# %%
cars
# Out:
#            일시 시도명  시군구 승용_관용   승용_자가용  승용_영업용     승용_계 승합_관용 승합_자가용 승합_영업용  \
# 0     2023-01  서울  강남구   154  207,692  19,642  227,488    54  4,112    587
# 268   2023-02  서울  강남구   153  207,975  19,749  227,877    54  4,102    570
# 536   2023-03  서울  강남구   155  209,267  19,559  228,981    54  4,084    566
# 804   2023-04  서울  강남구   152  210,122  19,345  229,619    54  4,067    566
# 1072  2023-05  서울  강남구   152  210,387  19,155  229,694    54  4,065    566
# 1340  2023-06  서울  강남구   159  210,777  19,328  230,264    56  4,064    565
# 1608  2023-07  서울  강남구   162  211,275  19,167  230,604    56  4,042    561
# 1877  2023-08  서울  강남구   164  211,741  19,006  230,911    56  4,043    552
# 2146  2023-09  서울  강남구   158  211,949  18,861  230,968    57  4,020    556
# 2415  2023-10  서울  강남구   159  212,274  18,962  231,395    56  4,030    550
# 2684  2023-11  서울  강남구   161  212,390  18,512  231,063    57  4,026    546
# ...

# %%
cars_kangnam = cars[['일시','승용_영업용']]

# %%
# df = df.reset_index(drop=True)

# %%
plt.plot(cars_kangnam['일시'], cars_kangnam['승용_영업용'])

# %%
cnt = cars_kangnam[:12]['승용_영업용']

# %%
cnt
# Out:
# 0       19,642
# 268     19,749
# 536     19,559
# 804     19,345
# 1072    19,155
# 1340    19,328
# 1608    19,167
# 1877    19,006
# 2146    18,861
# 2415    18,962
# 2684    18,512
# 2953    18,168
# Name: 승용_영업용, dtype: object

# %%
cars_kangnam = cars_kangnam.reset_index(drop=True)

# %%
cars_kangnam
# Out:
#          일시  승용_영업용
# 0   2023-01  19,642
# 1   2023-02  19,749
# 2   2023-03  19,559
# 3   2023-04  19,345
# 4   2023-05  19,155
# 5   2023-06  19,328
# 6   2023-07  19,167
# 7   2023-08  19,006
# 8   2023-09  18,861
# 9   2023-10  18,962
# 10  2023-11  18,512
# 11  2023-12  18,168
# 12  2024-01  17,940
# 13  2024-02  17,423
# 14  2024-03  17,038
# 15  2024-04  16,813
# 16  2024-05  16,595
# 17  2024-06  17,319
# 18  2024-07  17,130
# 19  2024-08  16,964
# 20  2024-09  16,437
# 21  2024-10  14,409
# 22  2024-11  14,071
# 23  2024-12  14,347
# 24  2025-01  14,177
# 25  2025-02  14,053

# %%
plt.plot(cars_kangnam['일시'], cars_kangnam['승용_영업용'])

# %%
cnt.reset_index(drop=True)
# Out:
# 0     19,642
# 1     19,749
# 2     19,559
# 3     19,345
# 4     19,155
# 5     19,328
# 6     19,167
# 7     19,006
# 8     18,861
# 9     18,962
# 10    18,512
# 11    18,168
# Name: 승용_영업용, dtype: object

# %%
cnt = cnt.str.replace(',', '').astype(int)

# %%
cnt
# Out:
# 0       19642
# 268     19749
# 536     19559
# 804     19345
# 1072    19155
# 1340    19328
# 1608    19167
# 1877    19006
# 2146    18861
# 2415    18962
# 2684    18512
# 2953    18168
# Name: 승용_영업용, dtype: int64

# %%
car_2023 = sum(cnt)/12

# %%
cnt2 = cnt = cars_kangnam[12:24]['승용_영업용']

# %%
cnt2
# Out:
# 12    17,940
# 13    17,423
# 14    17,038
# 15    16,813
# 16    16,595
# 17    17,319
# 18    17,130
# 19    16,964
# 20    16,437
# 21    14,409
# 22    14,071
# 23    14,347
# Name: 승용_영업용, dtype: object

# %%
cnt2 = cnt2.str.replace(',', '').astype(int)

# %%
cnt3 = cars_kangnam[:24]['승용_영업용']

# %%
cnt3 = cnt3.str.replace(',', '').astype(int)

# %%
cnt3
# Out:
# 0     19642
# 1     19749
# 2     19559
# 3     19345
# 4     19155
# 5     19328
# 6     19167
# 7     19006
# 8     18861
# 9     18962
# 10    18512
# 11    18168
# 12    17940
# 13    17423
# 14    17038
# 15    16813
# 16    16595
# 17    17319
# 18    17130
# 19    16964
# 20    16437
# 21    14409
# 22    14071
# 23    14347
# Name: 승용_영업용, dtype: int64

# %%
car_2024 = sum(cnt2)/12

# %%
plt.plot(cars_kangnam[:12]['일시'], cnt)
plt.title('2023 cars')
plt.xlabel('month')
plt.ylabel('count')
plt.show()

# %%
fig, ax = plt.subplots()
plt.xticks(rotation=45)  # 45도 회전
ax.plot(cars_kangnam[:24]['일시'], cnt3)
ax.set_title('2023 cars')
ax.set_xlabel('month')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

query = "법인 차량"
news_list = []

for page in range(1, 11):  # 10페이지 크롤링
    url = f"https://search.naver.com/search.naver?where=news&query={query}&start={page*10-9}"
    res = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    soup = BeautifulSoup(res.text, "html.parser")
    
    for item in soup.select("ul.list_news div.news_area"):
        title = item.select_one("a.news_tit").text
        link = item.select_one("a.news_tit")["href"]
        news_list.append((title, link))

df = pd.DataFrame(news_list, columns=["제목", "링크"])
print(df.head())
# Out:
#                                          제목  \
# 0              법인 고가 차량 급증…연두색 번호판 "눈치 안본다"
# 1        '이재명 법인카드' 재판부의 질문 "2만 원? 오기 아닌가?"
# 2           美작가 아샴, 래퍼 퀘이보·하이브美법인 상대 저작권 소송
# 3  청년창업기업 지방수의계약 한도↑, 농업법인 태양광 잉여전력 거래 허...
# 4         “GM, 가장 앞선 SDV 구현…韓 연구개발법인 핵심 역할”
#
#                                                   링크
# 0  https://www.newsis.com/view/NISX20250410_00031...
# 1  https://www.ohmynews.com/NWS_Web/View/at_pg.as...
# 2  https://www.yna.co.kr/view/AKR2025040807970007...
# 3         https://www.etoday.co.kr/news/view/2460794
# 4              https://www.etnews.com/20250408000376

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# 크롬드라이버 경로 지정
driver_path = r"C:\chromedriver-win64\chromedriver-win64\chromedriver.exe"  # 여기를 너가 압축 푼 경로로 바꿔줘

options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": "C:/data_5",  # 엑셀 저장할 폴더 경로
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

# 드라이버 실행
driver = webdriver.Chrome(service=Service(driver_path), options=options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: C:\chromedriver-win64\chromedriver-win64\chromedriver.exe
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[36], line 17
#       9 options.add_experimental_option("prefs", {
#      10     "download.default_directory": "C:/data_5",  # 엑셀 저장할 폴더 경로
#      11     "download.prompt_for_download": False,
#      12     "download.directory_upgrade": True,
#      13     "safebrowsing.enabled": True
#      14 })
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

query = "법인 차량 제도"
articles = []

for page in range(1, 6):  # 5페이지 (기사 50개)
    start = (page - 1) * 10 + 1
    url = f"https://search.naver.com/search.naver?where=news&query={query}&start={start}"
    headers = {"User-Agent": "Mozilla/5.0"}
    
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")
    
    news_items = soup.select("ul.list_news li.bx")
    for item in news_items:
        title_tag = item.select_one("a.news_tit")
        if title_tag:
            title = title_tag["title"]
            link = title_tag["href"]
            articles.append((title, link))

df = pd.DataFrame(articles, columns=["제목", "링크"])
print(df.head())

# 엑셀로 저장
df.to_excel("news_articles.xlsx", index=False)

# %%
pip install konlpy wordcloud matplotlib

# %%
from wordcloud import WordCloud

# %%
pip install wordcloud matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re

# ✅ 뉴스 기사 제목 크롤링
query = "법인차 제도"
articles = []

for page in range(1, 6):  # 5페이지 = 약 50개 기사
    start = (page - 1) * 10 + 1
    url = f"https://search.naver.com/search.naver?where=news&query={query}&start={start}"
    headers = {"User-Agent": "Mozilla/5.0"}
    
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")
    
    news_items = soup.select("ul.list_news li.bx")
    for item in news_items:
        title_tag = item.select_one("a.news_tit")
        if title_tag:
            articles.append(title_tag["title"])

# ✅ 제목 텍스트 결합 후 정제
text = " ".join(articles)
text = re.sub("[^가-힣\s]", "", text)  # 한글만 남기기

# ✅ 단순 공백 기준 단어 분리
words = text.split()
words = [word for word in words if len(word) > 1]  # 1글자 제거

# ✅ 빈도수 집계
word_freq = Counter(words)

# ✅ 워드클라우드 생성
wc = WordCloud(
    font_path="c:/Windows/Fonts/malgun.ttf",  # 한글 폰트 (윈도우 기준)
    width=800,
    height=400,
    background_color="white"
)
wc.generate_from_frequencies(word_freq)

# ✅ 시각화 출력
plt.figure(figsize=(12, 6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title(f"네이버 뉴스 워드클라우드: {query}", fontsize=16)
plt.show()
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# <>:29: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\erety\AppData\Local\Temp\ipykernel_12016\3598751770.py:29: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub("[^가-힣\s]", "", text)  # 한글만 남기기
# C:\Users\erety\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\erety\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\erety\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import pandas as pd

# 드라이버 경로 설정
driver_path = r"C:\Users\erety\Downloads\chromedriver-win64\chromedriver.exe"

options = Options()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(service=Service(driver_path), options=options)

# 해당 URL로 이동
url = "https://stat.molit.go.kr/portal/cate/statView.do?hFormId=1244&hRsId=58"  # 실제 테이블 주소로 바꿔줘야 함
driver.get(url)
time.sleep(3)

# ✅ 자바스크립트로 내부 테이블 스크롤 조작 (예시: 수직+수평 스크롤)
scroll_script = """
var innerDiv = document.querySelector(".pvtTableContainer > div");  // ← 내부 div 클래스 수정 필요
innerDiv.scrollTop = innerDiv.scrollHeight;
innerDiv.scrollLeft = innerDiv.scrollWidth;
"""
driver.execute_script(scroll_script)
time.sleep(2)

# ✅ 테이블 HTML 추출
table_html = driver.find_element(By.CLASS_NAME, "pvtTable").get_attribute("outerHTML")  # 클래스명은 실제 페이지 기준
driver.quit()

# ✅ BeautifulSoup으로 테이블 파싱
soup = BeautifulSoup(table_html, "html.parser")
table = soup.find("table")
df = pd.read_html(str(table))[0]

# ✅ 결과 확인
print(df.head())

# %%
import plotly.graph_objects as go

# %%
# 그래프 생성
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x, y=y,
    mode='lines+markers',
    name='매출',
    line=dict(shape='spline')  # 부드러운 곡선
))

# 레이아웃 설정
fig.update_layout(
    title='월별 매출 변화',
    xaxis_title='월',
    yaxis_title='매출액',
    template='plotly_white'
)

fig.show()
